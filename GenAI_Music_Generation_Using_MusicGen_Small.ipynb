# %%
# Install library
# !pip install --upgrade pip
# !pip install --upgrade transformers scipy
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 82.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 MB 59.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 65.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
# ...

# %%
# Import library
from transformers import AutoProcessor, MusicgenForConditionalGeneration
from IPython.display import Audio

# %%
# Load the processor and model
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small")

# Prepare the input text
track_descriptions = [
    "80s pop track with bassy drums and synth",
    "90s rock song with loud guitars and heavy drums"
]
inputs = processor(
    text=track_descriptions,
    padding=True,
    return_tensors="pt",
)

# Generate audio values
audio_values = model.generate(**inputs, max_new_tokens=256)

# Get the sampling rate
sampling_rate = model.config.audio_encoder.sampling_rate

# Play the generated audio
Audio(audio_values[0].numpy(), rate=sampling_rate)
# Out:
# preprocessor_config.json:   0%|          | 0.00/275 [00:00<?, ?B/s]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load the processor and model
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small")

# Prepare the input text with new track descriptions
track_descriptions = [
    "chill lo-fi beats with soft piano and light percussion",
    "energetic EDM track with catchy synth melodies and heavy bass drops",
    "smooth jazz piece with saxophone and gentle guitar",
    "uplifting country song with acoustic guitar and harmonica"
]
inputs = processor(
    text=track_descriptions,
    padding=True,
    return_tensors="pt",
)

# Generate audio values
audio_values = model.generate(**inputs, max_new_tokens=256)

# Get the sampling rate
sampling_rate = model.config.audio_encoder.sampling_rate

# Play the generated audio
Audio(audio_values[0].numpy(), rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Load the processor and model
processor = AutoProcessor.from_pretrained("facebook/musicgen-small")
model = MusicgenForConditionalGeneration.from_pretrained("facebook/musicgen-small")

# Prepare the input text with new track descriptions
track_descriptions = [
    "mellow acoustic ballad with heartfelt lyrics and soft guitar",
    "intense hip-hop track with deep bass and rapid-fire lyrics",
    "upbeat pop song with catchy hooks and vibrant instrumentation",
    "epic orchestral score with sweeping strings and powerful brass"
]
inputs = processor(
    text=track_descriptions,
    padding=True,
    return_tensors="pt",
)

# Generate audio values
audio_values = model.generate(**inputs, max_new_tokens=256)

# Get the sampling rate
sampling_rate = model.config.audio_encoder.sampling_rate

# Play the generated audio
Audio(audio_values[0].numpy(), rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
